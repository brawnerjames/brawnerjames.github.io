# %%
import pandas as pd

# %%
csv_file = "WebVisualizations/weatherdata.csv"
df = pd.read_csv(csv_file)

# %%
df.set_index("Unnamed: 0")
df.rename(columns = {"lat":"Lat", "lon":"Lon", "city":"City", "clouds":"Clouds", "country":"Country", "humidity":"Humidity", "max_temp":"Max Temperature", "wind_sp": "Wind Speed"})
# Out:
#      Unnamed: 0    Lat     Lon             City  Clouds Country        date  \
# 0             0 -46.19  168.86          mataura      72      NZ  1579921241
# 1             1 -41.41  175.52          waipawa      83      NZ  1579921369
# 2             2 -51.62  -69.22     rio gallegos      30      AR  1579921082
# 3             3  40.60 -124.16          fortuna      90      US  1579920999
# 4             4  71.69  128.87            tiksi       0      RU  1579921258
# ..          ...    ...     ...              ...     ...     ...         ...
# 539         539 -22.27   28.75       mathathane       2      BW  1579921682
# 540         540 -41.45  147.17       launceston      90      AU  1579921407
# 541         541  43.12    5.80   sanary-sur-mer      90      FR  1579921682
# 542         542 -12.04  -77.03             lima     100      PE  1579921502
# 543         543   5.88  -55.08  nieuw amsterdam      22      SR  1579921683
#
#      Humidity  Max Temperature  Wind Speed
# ...

# %%
data_html = df.to_html(buf=None, columns=None, col_space=None, header=True, index=True, na_rep='NaN', formatters=None, float_format=None, sparsify=None, index_names=True, justify=None, bold_rows=True, classes=None, escape=True, max_rows=None, max_cols=None, show_dimensions=False, notebook=False)
print(data_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>city</th>
#       <th>clouds</th>
#       <th>country</th>
#       <th>date</th>
#       <th>humidity</th>
#       <th>max_temp</th>
#       <th>wind_sp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>-46.19</td>
#       <td>168.86</td>
#       <td>mataura</td>
#       <td>72</td>
#       <td>NZ</td>
#       <td>1579921241</td>
#       <td>60</td>
#       <td>66.99</td>
#       <td>8.01</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>-41.41</td>
#       <td>175.52</td>
#       <td>waipawa</td>
#       <td>83</td>
#       <td>NZ</td>
#       <td>1579921369</td>
#       <td>60</td>
#       <td>75.20</td>
#       <td>19.46</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
#       <td>-51.62</td>
# ...

# %%
data_file = open("data.html", "w")
data_file.write(data_html)
data_file.close()
